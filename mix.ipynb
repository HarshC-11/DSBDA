# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("heart_cleveland_upload.csv")

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     69    1   0       160   234    1        2      131      0      0.1
# 1     69    0   0       140   239    0        0      151      0      1.8
# 2     66    0   0       150   226    0        0      114      0      2.6
# 3     65    1   0       138   282    1        2      174      0      1.4
# 4     64    1   0       110   211    0        2      144      1      1.8
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 292   40    1   3       152   223    0        0      181      0      0.0
# 293   39    1   3       118   219    0        0      140      0      1.2
# 294   35    1   3       120   198    0        0      130      1      1.6
# 295   35    0   3       138   183    0        0      182      0      1.4
# 296   35    1   3       126   282    0        2      156      1      0.0
#
#      slope  ca  thal  condition
# 0        1   1     0          0
# ...

# %%
df['condition'].value_counts()
# Out:
# 0    160
# 1    137
# Name: condition, dtype: int64

# %%
df.isnull().sum()
# Out:
# age          0
# sex          0
# cp           0
# trestbps     0
# chol         0
# fbs          0
# restecg      0
# thalach      0
# exang        0
# oldpeak      0
# slope        0
# ca           0
# thal         0
# condition    0
# dtype: int64

# %%
x = df['thalach'].values
y = df['condition'].values
plt.plot(x,y)
plt.show()

# %%
# x = df['condition'].value_counts()
# target = x.values

# labels = ['less severe', 'severe', 'moderate', 'high', 'very high']

# plt.bar(labels, target)
# plt.plot()


plt.bar(df['condition'], df['oldpeak'])
plt.plot()
# Out:
# []

# %%
y = df['sex'].value_counts().values
x = ['Men', 'Female']
plt.xlabel('Gender')
plt.ylabel('count')
# plt.legend()
plt.title('bar graph')

plt.bar(x,y, color='red')
plt.plot()
# Out:
# []

# %%
sns.countplot(df['sex'], data=df['sex'])
# Out:
# C:\Users\Harsh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
hm = df.corr()
ax = sns.heatmap(hm)
fig = plt.gcf()
fig.set_size_inches(12, 10)
# sns.heatmap(hm, annot=True)

# %%
histogram = plt.hist(df['thalach'])
fig = plt.gcf()
fig.set_size_inches(12,10)

# %%
ax = plt.scatter(df['age'], df['thalach'])
fig = plt.gcf()
fig.set_size_inches(12,10)

# %%
df['condition'].value_counts()
# Out:
# 0    160
# 1    137
# Name: condition, dtype: int64

# %%
# plt.pie(df['condition'].value_counts().values, labels= ['less severe', 'severe', 'moderate', 'high', 'very high'], autopct= "%1.1f%%")
# plt.show


mylabels= ['low','high']
ax = plt.pie(df['condition'].value_counts().values, labels=mylabels)
fig = plt.gcf()
fig.set_size_inches(12,10)
plt.plot()
# Out:
# []

# %%
df['thalach'].value_counts()
# Out:
# 162    11
# 160     9
# 163     9
# 152     8
# 125     7
#        ..
# 128     1
# 129     1
# 134     1
# 137     1
# 202     1
# Name: thalach, Length: 91, dtype: int64

# %%
ax = sns.boxplot(data=[df['age'], df['thalach'], df['trestbps']])
fig = plt.gcf()
fig.set_size_inches(12,10)
plt.plot()
# Out:
# []

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data for scatterplot and boxplots
# x = [1, 2, 3, 4, 5]
x = df['trestbps']
y = df['chol']
# y = [6, 7, 8, 9, 10]
# categories = ['A', 'A', 'B', 'B', 'B']

# Create a scatterplot
sns.scatterplot(x=x, y=y)

# Add boxplots
# sns.boxplot(x=categories, y=y, width=0.3, boxprops={'alpha': 0.5}, showfliers=False)
sns.boxplot(data=[df['trestbps'],df['chol']])

# Customize the plot
plt.legend(title='Categories')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatterplot with Boxplots')

# Display the plot
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'condition'],
#       dtype='object')

# %% [markdown]
# # WEB SCRAPPING

# %%
import requests
import bs4

# %%
req = requests.get("https://www.flipkart.com/oneplus-nord-ce-2-lite-5g-black-dusk-128-gb/p/itm537fc2aa73747?pid=MOBGHBZHB7YJT5HF&lid=LSTMOBGHBZHB7YJT5HFXLGAJE&marketplace=FLIPKART&q=oneplus+mobile&store=tyy%2F4io&srno=s_1_1&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&fm=organic&iid=89df5ecc-ffc0-4da7-988c-6c06fd708415.MOBGHBZHB7YJT5HF.SEARCH&ppt=hp&ppn=homepage&ssid=2qwmmkgymo0000001685187125123&qH=9f1419b282422384")

# %%
req
# Out:
# <Response [200]>

# %%
req.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.914d0a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
soup = bs4.BeautifulSoup(req.text)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
reviews = soup.findAll('div',{'class':'t-ZTKy'})
for review in reviews:
    print(review.get_text() + "\n\n")
# Out:
# Just now I received my phoneDesign & build quality is good according to price rangeCamera overall goodDisplay & performance is also good for normal usage (less heavy uses)Features are also very smooth It's my first day of usage so I'll edit my review after useThank you.READ MORE
#
#
# A Midrange phone from OnePlus.Why I choose this phone is only because of the Brand value.We have more other options like Vivo T1 ,Realme 9,9pro , Oppo ,Motorola.But the OnePlus has their own premium feel The reason why I have given only 4 star:-1-The AMOLED display is not there.But it is not important.2- Wide angle lens is also not there.3- They have removed Alert slider.Other wise the phone is perfect. I am satisfied with this device 95%.You can go for it.The important thing is tha...READ MORE
#
#
# Very good mobile good camera everything is good i love This  mobile phone❤️READ MORE
#
#
# ...

# %%
names = soup.findAll('div',{'class':'row _3n8db9'})
for name in names:
    print(name.get_text() + "\n\n")
# Out:
# Ashutosh KashyapCertified Buyer, New Delhi10 months ago139092508PermalinkReport Abuse
#
#
# Flipkart CustomerCertified Buyer, Ernakulam District10 months ago108962055PermalinkReport Abuse
#
#
# Chakra SangamCertified Buyer, Coonoor8 months ago64491238PermalinkReport Abuse
#
#
# Prashant KumarCertified Buyer, New Delhi10 months ago10417PermalinkReport Abuse
#
#
# Sree LakshmiCertified Buyer, Kochi9 months ago3494961PermalinkReport Abuse
#
#
# Ritesh SinghCertified Buyer, Ballia District11 months ago108613837PermalinkReport Abuse
#
#
# Ehthishamul HaqueCertified Buyer, PernambutMay, 20221870660PermalinkReport Abuse
#
#
# DANISH SALVICertified Buyer, Rajsamand6 months ago575205PermalinkReport Abuse
#
#
# Saurav KumarCertified Buyer, Sheikhpura District7 months ago960384PermalinkReport Abuse
#
#
# Vamsi Krishna PVVNCertified Buyer, Hyderabad11 months ago2247957PermalinkReport Abuse

# %%
prod_desc = soup.findAll('div',{'class':'_1AtVbE col-12-12'})
for prod in prod_desc:
    print(prod.get_text() + "\n\n")
# Out:
#  Add to cart Buy Now
#
#
#
#
#
# Compare
#
#
# Share
#
#
# OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)  (6 GB RAM)4.463,987 Ratings & 4,611 ReviewsExtra ₹1009 off₹18,990₹19,9995% offi+ ₹49 Secured Packaging Fee
#
#
# Available offersBank Offer10% off on Bank of Baroda Credit Card Transactions, up to ₹1,000 on orders of ₹8,000 and aboveT&CBank OfferFlat ₹1250  Discount on HDFC Bank Credit Card EMI Transactions on orders of ₹15,000 and aboveT&CBank Offer10% off on Bank of Baroda Credit Card EMI Transactions, up to ₹1,500 on orders of ₹8,000 and aboveT&CSpecial PriceGet extra ₹1009 off (price inclusive of cashback/coupon)T&CView 12 more offers
#
#
# 12 monthsKnow More
#
#
# ColorBlack DuskBlue TidePlease select a Color to proceed✕
#
#
# DeliveryCheckEnter pincodeDelivery by31 May, Wednesday|Free₹40?if ordered before 10:43 AMView Details
#
#
# SellereFactorTechies4.87 Days Replacement Policy?See other sellers
#
#
# ...
